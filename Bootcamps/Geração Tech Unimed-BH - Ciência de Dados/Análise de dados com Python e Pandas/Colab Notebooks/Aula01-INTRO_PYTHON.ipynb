# %% [markdown]
# # **INTRODUÇÃO PYTHON**

# %%
print("Olá mundo")
# Out:
# Olá mundo

# %%
print("Aprendendo python")
# Out:
# Aprendendo python

# %% [markdown]
# ## OPERAÇÕES COM **PYTHON**

# %%
a = 10
b = 6

# %% [markdown]
# **soma**

# %%
a + b
# Out:
# 16

# %% [markdown]
# **subtração**

# %%
a - b
# Out:
# 4

# %% [markdown]
# **divisão**

# %%
a / b
# Out:
# 1.6666666666666667

# %% [markdown]
# **multiplicação**

# %%
a * b
# Out:
# 60

# %% [markdown]
# ## METODOS DE STRING COM **PYTHON**

# %%
frase = "Python para análise de dados"

# %%
print(frase[0])
# Out:
# P

# %%
print(frase[0:10])
# Out:
# Python par

# %%
print(frase[10:])
# Out:
# a análise de dados

# %%
print(frase[:17])
# Out:
# Python para análi

# %%
print(frase.count("dados"))
# Out:
# 1

# %%
print(frase.lower())
# Out:
# python para análise de dados

# %%
frase = frase.upper()

# %%
print(frase)
# Out:
# PYTHON PARA ANÁLISE DE DADOS

# %%
print(frase.lower().replace("python","frases"))
# Out:
# frases para análise de dados
